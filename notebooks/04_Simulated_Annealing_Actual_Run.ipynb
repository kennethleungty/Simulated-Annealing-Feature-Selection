# %% [markdown]
# # Simulated Annealing for Feature Selection
# ## 04 - Simulated Annealing Algorithm (Actual Demo Run)
# ___

# %%
# cd ..

# %%
from src.main import simulated_annealing

# %%
import pandas as pd

# %%
# Load data
PATH = './data/processed/'
X_train = pd.read_csv(PATH + 'X_train.csv')
y_train = pd.read_csv(PATH + 'y_train.csv')

# %%
results, best_metric, best_subset_cols = simulated_annealing(X_train, y_train)
# Out:
# Starting Iteration 0
# Local improvement in metric from   0.8240 to   0.8380  - parameters accepted
# Global improvement in metric from   0.8240 to   0.8380  - best parameters updated
# Starting Iteration 1
# Local improvement in metric from   0.8380 to   0.8420  - parameters accepted
# Global improvement in metric from   0.8380 to   0.8420  - best parameters updated
# Starting Iteration 2
# New subset has worse performance, therefore reject. Metric change:  -0.0080 acceptance probability: 0.9884 random number: 0.9958
# Starting Iteration 3
# Local improvement in metric from   0.8420 to   0.8670  - parameters accepted
# Global improvement in metric from   0.8420 to   0.8670  - best parameters updated
# Starting Iteration 4
# New subset has worse performance but still accept. Metric change:  -0.0290 acceptance probability: 0.9432 random number: 0.8004
# Starting Iteration 5
# Local improvement in metric from   0.8380 to   0.8480  - parameters accepted
# Starting Iteration 6
# New subset has worse performance but still accept. Metric change:  -0.0030 acceptance probability: 0.9917 random number: 0.5321
# Starting Iteration 7
# New subset has worse performance but still accept. Metric change:  -0.1550 acceptance probability: 0.6011 random number: 0.1577
# Starting Iteration 8
# New subset has worse performance, therefore reject. Metric change:  -0.0730 acceptance probability: 0.7543 random number: 0.8422
# Starting Iteration 9
# Local improvement in metric from   0.6900 to   0.8450  - parameters accepted
# Starting Iteration 10
# Local improvement in metric from   0.8450 to   0.8550  - parameters accepted
# Starting Iteration 11
# New subset has worse performance but still accept. Metric change:  -0.0610 acceptance probability: 0.6813 random number: 0.3443
# Starting Iteration 12
# Local improvement in metric from   0.7940 to   0.8550  - parameters accepted
# Starting Iteration 13
# New subset has worse performance but still accept. Metric change:  -0.0110 acceptance probability: 0.9087 random number: 0.5703
# Starting Iteration 14
# New subset has worse performance but still accept. Metric change:  -0.0110 acceptance probability: 0.8934 random number: 0.3851
# Starting Iteration 15
# Local improvement in metric from   0.8330 to   0.8420  - parameters accepted
# Starting Iteration 16
# New subset has worse performance, therefore reject. Metric change:  -0.0440 acceptance probability: 0.5359 random number: 0.9844
# Starting Iteration 17
# New subset has worse performance but still accept. Metric change:  -0.0020 acceptance probability: 0.9672 random number: 0.1526
# Starting Iteration 18
# New subset has worse performance but still accept. Metric change:  -0.0150 acceptance probability: 0.7450 random number: 0.2993
# Starting Iteration 19
# New subset has worse performance, therefore reject. Metric change:  -0.0170 acceptance probability: 0.6754 random number: 0.8543
# Starting Iteration 20
# Local improvement in metric from   0.8250 to   0.8360  - parameters accepted
# Starting Iteration 21
# New subset has worse performance, therefore reject. Metric change:  -0.1690 acceptance probability: 0.0045 random number: 0.5997
# Starting Iteration 22
# New subset has worse performance, therefore reject. Metric change:  -0.0240 acceptance probability: 0.4057 random number: 0.5554
# Starting Iteration 23
# New subset has worse performance, therefore reject. Metric change:  -0.0210 acceptance probability: 0.3951 random number: 0.9338
# Starting Iteration 24
# New subset has worse performance, therefore reject. Metric change:  -0.0350 acceptance probability: 0.1619 random number: 0.9971
# Starting Iteration 25
# Local improvement in metric from   0.8360 to   0.8470  - parameters accepted
# Starting Iteration 26
# Local improvement in metric from   0.8470 to   0.8640  - parameters accepted
# Starting Iteration 27
# New subset has worse performance but still accept. Metric change:  -0.0030 acceptance probability: 0.7756 random number: 0.0265
# Starting Iteration 28
# New subset has worse performance, therefore reject. Metric change:  -0.0270 acceptance probability: 0.0678 random number: 0.8815
# Temperature 0.008528496017705896 below threshold. Termination condition met

# %%
results
# Out:
#    Iteration Feature Count         Feature Set Metric Best Metric  \
# 0          1             4        [8, 2, 4, 5]  0.838       0.838
# 1          2             5     [1, 2, 4, 5, 8]  0.842       0.842
# 2          3             5     [1, 2, 4, 5, 8]  0.834       0.842
# 3          4             5     [0, 1, 2, 5, 8]  0.867       0.867
# 4          5             5     [0, 1, 2, 6, 8]  0.838       0.867
# 5          6             5     [0, 1, 3, 6, 8]  0.848       0.867
# 6          7             5     [0, 1, 2, 3, 6]  0.845       0.867
# 7          8             4        [0, 2, 3, 6]   0.69       0.867
# 8          9             4        [0, 2, 3, 6]  0.617       0.867
# 9         10             5     [0, 2, 3, 6, 8]  0.845       0.867
# 10        11             4        [0, 8, 2, 3]  0.855       0.867
# 11        12             4        [8, 2, 3, 7]  0.794       0.867
# 12        13             4        [8, 2, 5, 7]  0.855       0.867
# 13        14             4        [8, 4, 5, 7]  0.844       0.867
# 14        15             5     [4, 5, 6, 7, 8]  0.833       0.867
# 15        16             5     [3, 4, 5, 7, 8]  0.842       0.867
# 16        17             5     [3, 4, 5, 7, 8]  0.798       0.867
# 17        18             4        [8, 3, 4, 5]   0.84       0.867
# 18        19             3           [8, 4, 5]  0.825       0.867
# 19        20             3           [8, 4, 5]  0.808       0.867
# 20        21             3           [8, 3, 5]  0.836       0.867
# 21        22             3           [8, 3, 5]  0.667       0.867
# 22        23             3           [8, 3, 5]  0.812       0.867
# 23        24             3           [8, 3, 5]  0.815       0.867
# 24        25             3           [8, 3, 5]  0.801       0.867
# 25        26             4        [8, 0, 3, 5]  0.847       0.867
# 26        27             5     [0, 2, 3, 5, 8]  0.864       0.867
# 27        28             6  [0, 2, 3, 5, 7, 8]  0.861       0.867
# 28        29             6  [0, 2, 3, 5, 7, 8]  0.834       0.867
#
#    Acceptance Probability Random Number   Outcome
# 0                       -             -  Improved
# 1                       -             -  Improved
# 2                0.988412      0.995764    Reject
# 3                       -             -  Improved
# 4                0.943198      0.800376    Accept
# 5                       -             -  Improved
# 6                0.991662      0.532136    Accept
# 7                0.601126      0.157681    Accept
# 8                0.754274      0.842234    Reject
# 9                       -             -  Improved
# 10                      -             -  Improved
# 11               0.681332      0.344293    Accept
# 12                      -             -  Improved
# 13               0.908674      0.570306    Accept
# 14               0.893446      0.385079    Accept
# 15                      -             -  Improved
# 16               0.535919      0.984426    Reject
# 17               0.967193      0.152562    Accept
# 18               0.745034      0.299258    Accept
# 19               0.675411      0.854259    Reject
# 20                      -             -  Improved
# 21               0.004518      0.599736    Reject
# 22               0.405703      0.555412    Reject
# 23                0.39508      0.933798    Reject
# 24               0.161877      0.997142    Reject
# 25                      -             -  Improved
# 26                      -             -  Improved
# 27               0.775577      0.026544    Accept
# 28               0.067815       0.88148    Reject

# %%
best_metric
# Out:
# 0.867

# %%
best_subset_cols
# Out:
# ['Pclass', 'Sex', 'Age', 'Fare', 'Title']
